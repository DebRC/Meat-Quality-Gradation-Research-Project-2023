# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import time
import os
from IPython.display import clear_output

# %%
files = ['Good', 'Intermediate', 'Bad']
address = '/media/debrc/Data/Codings/Meat-Gradation-PROJ/Dataset/Chicken/'

# %%
data = {}
for f in files:
    data[f]=[]

# %%
for col in files:
    os.chdir(address+col)
    for i in os.listdir(os.getcwd()):
        if i.endswith('.jpg'):
            data[col].append(i)
# Out:
# /media/debrc/Data/Codings/Meat-Gradation-PROJ/Dataset/Chicken/Good
# /media/debrc/Data/Codings/Meat-Gradation-PROJ/Dataset/Chicken/Intermediate
# /media/debrc/Data/Codings/Meat-Gradation-PROJ/Dataset/Chicken/Bad

# %%
# Out:
# {'Good': ['Sample 1 (a)(1).jpg',
#   'Sample 1 (A)(2).jpg',
#   'Sample 1 (a).jpg',
#   'Sample 1 (b)(1).jpg',
#   'Sample 1 (b)(2).jpg',
#   'Sample 1 (b)(3).jpg',
#   'Sample 1 (b).jpg',
#   'Sample 1 (c)(1).jpg',
#   'Sample 1 (c)(2).jpg',
#   'Sample 1 (c).jpg',
#   'Sample 1 (d)(1).jpg',
#   'Sample 1 (d)(2).jpg',
#   'Sample 1 (d)(3).jpg',
#   'Sample 1 (d)(4).jpg',
#   'Sample 1 (d)(5).jpg',
#   'Sample 1 (d)(6).jpg',
#   'Sample 1 (d).jpg',
#   'Sample 1(a)(1).jpg',
#   'Sample 1(a)(2).jpg',
#   'Sample 1(a)(3).jpg',
#   'Sample 1(a)(4).jpg',
#   'Sample 1(a).jpg',
#   'Sample 1(b)(1).jpg',
#   'Sample 1(b)(2).jpg',
#   'Sample 1(b)(3).jpg',
#   'Sample 1(b)(4).jpg',
#   'Sample 1(b).jpg',
#   'Sample 4 (a).jpg',
#   'Sample 4 (b)(1).jpg',
#   'Sample 4 (b).jpg',
#   'Sample 4 (c)(1).jpg',
#   'Sample 4 (c)(2).jpg',
#   'Sample 4 (c).jpg',
#   'Sample 4 (d)(1).jpg',
#   'Sample 4 (d)(2).jpg',
#   'Sample 4 (d).jpg',
#   'Sample 4(a)(1).jpg',
#   'Sample 4(a)(2).jpg',
#   'Sample 4(a)(3).jpg',
#   'Sample 4(a)(4).jpg',
#   'Sample 4(a)(5).jpg',
#   'Sample 4(a)(6).jpg',
#   'Sample 4(a).jpg',
#   'Sample 4(b)(1).jpg',
#   'Sample 4(b)(2).jpg',
#   'Sample 2(d)(2).jpg',
#   'Sample 2(d)(3).jpg',
#   'Sample 2(d).jpg',
#   'Sample 3 ( a).jpg',
#   'Sample 3 (a)(1).jpg',
#   'Sample 3 (a).jpg',
#   'Sample 3 (b)(1).jpg',
#   'Sample 3 (b)(2).jpg',
#   'Sample 3 (b).jpg',
#   'Sample 3 (c)(1).jpg',
#   'Sample 3 (c)(2).jpg',
#   'Sample 3 (c)(3).jpg',
#   'Sample 3 (c)(4).jpg',
#   'Sample 3 (c)(5).jpg',
#   'Sample 3 (c)(6).jpg',
#   'Sample 3 (c)(7).jpg',
#   'Sample 3 (c)(8).jpg',
#   'Sample 3 (c).jpg',
#   'Sample 3 (d)(1).jpg',
#   'Sample 5 (c)(3).jpg',
#   'Sample 5 (c)(4).jpg',
#   'Sample 5 (c).jpg',
#   'Sample 5 (d)(1).jpg',
#   'Sample 5 (d)(2).jpg',
#   'Sample 5 (d)(3).jpg',
#   'Sample 5 (d)(4).jpg',
#   'Sample 5 (d)(5).jpg',
#   'Sample 5 (d).jpg',
#   'Sample 5(a)(1).jpg',
#   'Sample 5(a)(2).jpg',
#   'Sample 5(a)(3).jpg',
#   'Sample 5(a)(4).jpg',
#   'Sample 5(a)(5).jpg',
#   'Sample 5(a)(6).jpg',
#   'Sample 5(a)(7).jpg',
#   'Sample 5(a).jpg',
#   'Sample 5(b)(1).jpg',
#   'Sample 5(b)(2).jpg',
#   'Sample 5(b)(3).jpg',
#   'Sample 5(b)(4).jpg',
#   'Sample 5(b)(5).jpg',
#   'Sample 5(b).jpg',
#   'Sample 5(c)(1).jpg',
#   'Sample 5(c)(2).jpg',
#   'Sample 5(c).jpg',
#   'Sample 5(d)(1).jpg',
#   'Sample 5(d)(2).jpg',
#   'Sample 5(d).jpg',
#   'Sample 1(c)(1).jpg',
#   'Sample 2(d)(1).jpg',
#   'Sample 3 (d)(2).jpg',
#   'Sample 3(b).jpg',
#   'Sample 4(b)(3).jpg',
#   'Sample 5 (c)(2).jpg',
#   'Sample 1(c)(2).jpg',
#   'Sample 1(c)(3).jpg',
#   'Sample 1(c)(4).jpg',
#   'Sample 1(c).jpg',
#   'Sample 2 (b).jpg',
#   'Sample 2 (c)(1).jpg',
#   'Sample 2 (c).jpg',
#   'Sample 2 (d)(1).jpg',
#   'Sample 2 (d)(2).jpg',
#   'Sample 2 (d)(3).jpg',
#   'Sample 2 (d).jpg',
#   'Sample 2(a)(1).jpg',
#   'Sample 2(a)(2).jpg',
#   'Sample 2(a)(3).jpg',
#   'Sample 2(a)(4).jpg',
#   'Sample 2(a)(5).jpg',
#   'Sample 2(a)(6).jpg',
#   'Sample 2(a)(7).jpg',
#   'Sample 2(a).jpg',
#   'Sample 2(b)(1).jpg',
#   'Sample 2(b)(2).jpg',
#   'Sample 2(b)(3).jpg',
#   'Sample 2(b)(4).jpg',
#   'Sample 2(b)(5).jpg',
#   'Sample 2(b)(6).jpg',
#   'Sample 2(b).jpg',
#   'Sample 2(c)(1).jpg',
#   'Sample 2(c)(2).jpg',
#   'Sample 2(c)(3).jpg',
#   'Sample 2(c)(4).jpg',
#   'Sample 2(c)(5).jpg',
#   'Sample 2(c).jpg',
#   'Sample 3 (d)(3).jpg',
#   'Sample 3 (d)(4).jpg',
#   'Sample 3 (d)(5).jpg',
#   'Sample 3 (d)(6).jpg',
#   'Sample 3 (d)(7).jpg',
#   'Sample 3 (d)(8).jpg',
#   'Sample 3 (d).jpg',
#   'Sample 3((a).jpg',
#   'Sample 3(a)(1).jpg',
#   'Sample 3(a)(2).jpg',
#   'Sample 3(a)(3).jpg',
#   'Sample 3(a)(4).jpg',
#   'Sample 3(a).jpg',
#   'Sample 3(b)(1).jpg',
#   'Sample 3(b)(2).jpg',
#   'Sample 3(b)(3).jpg',
#   'Sample 3(b)(4).jpg',
#   'Sample 3(b)(5).jpg',
#   'Sample 4(b)(4).jpg',
#   'Sample 4(b)(5).jpg',
#   'Sample 4(B)(6).jpg',
#   'Sample 4(b).jpg',
#   'Sample 4(c)(1).jpg',
#   'Sample 4(c)(2).jpg',
#   'Sample 4(c)(3).jpg',
#   'Sample 4(c).jpg',
#   'Sample 4(d)(1).jpg',
#   'Sample 4(d)(2).jpg',
#   'Sample 4(d)(3).jpg',
#   'Sample 4(d)(4).jpg',
#   'Sample 4(d).jpg',
#   'Sample 5 (a)(1).jpg',
#   'Sample 5 (a).jpg',
#   'Sample 5 (b)(1).jpg',
#   'Sample 5 (B)(2).jpg',
#   'Sample 5 (b).jpg',
#   'Sample 5 (c)(1).jpg'],
#  'Intermediate': ['Sample 1 (a).jpg',
#   'Sample 1 (b).jpg',
#   'Sample 1 (c).jpg',
#   'Sample 1 (d).jpg',
#   'Sample 2(a).jpg',
#   'Sample 2(b).jpg',
#   'Sample 2(c).jpg',
#   'Sample 2(d).jpg',
#   'Sample 3(a).jpg',
#   'Sample 3(b).jpg',
#   'Sample 3(c).jpg',
#   'Sample 3(d).jpg',
#   'Sample 4 (a).jpg',
#   'Sample 4 (b).jpg',
#   'Sample 4 (c).jpg',
#   'Sample 4 (d).jpg',
#   'Sample 5(a).jpg',
#   'Sample 5(b).jpg',
#   'Sample 5(c).jpg',
#   'Sample 5(d).jpg'],
#  'Bad': ['Sample 1 (d).jpg',
#   'Sample 1(a)(1).jpg',
#   'Sample 1(a)(2).jpg',
#   'Sample 1(a)(3).jpg',
#   'Sample 1(a)(4).jpg',
#   'Sample 1(a)(5).jpg',
#   'Sample 1(a)(6).jpg',
#   'Sample 1(a)(7).jpg',
#   'Sample 1(a).jpg',
#   'Sample 1(b)(1).jpg',
#   'Sample 1(b)(2).jpg',
#   'Sample 1(b)(3).jpg',
#   'Sample 1(b)(4).jpg',
#   'Sample 1(b)(5).jpg',
#   'Sample 1(b)(6).jpg',
#   'Sample 1(b)(7).jpg',
#   'Sample 1(b).jpg',
#   'Sample 1(c)(1).jpg',
#   'Sample 1(c)(2).jpg',
#   'Sample 1(c)(3).jpg',
#   'Sample 4 (c)(2).jpg',
#   'Sample 4 (c)(3).jpg',
#   'Sample 4 (c)(4).jpg',
#   'Sample 4 (c)(5).jpg',
#   'Sample 4 (c).jpg',
#   'Sample 4 (d)(1).jpg',
#   'Sample 4 (d)(2).jpg',
#   'Sample 4 (d)(3).jpg',
#   'Sample 4 (d)(4).jpg',
#   'Sample 4 (d).jpg',
#   'Sample 4(a)(1).jpg',
#   'Sample 4(a)(2).jpg',
#   'Sample 4(a).jpg',
#   'Sample 4(b).jpg',
#   'Sample 4(c).jpg',
#   'Sample 4(d)(1).jpg',
#   'Sample 4(d).jpg',
#   'Sample 5 (a)(1).jpg',
#   'Sample 5 (a)(2).jpg',
#   'Sample 5 (a)(3).jpg',
#   'Sample 5 (a)(4).jpg',
#   'Sample 5 (a).jpg',
#   'Sample 2(d)(2).jpg',
#   'Sample 2(d)(3).jpg',
#   'Sample 2(d).jpg',
#   'Sample 3 (b)(1).jpg',
#   'Sample 3 (b)(2).jpg',
#   'Sample 3 (b)(3).jpg',
#   'Sample 3 (b).jpg',
#   'Sample 3 (c)(1).jpg',
#   'Sample 3 (c)(2).jpg',
#   'Sample 3 (c)(3).jpg',
#   'Sample 3 (c).jpg',
#   'Sample 3 (d)(1).jpg',
#   'Sample 3 (d)(2).jpg',
#   'Sample 3 (d)(3).jpg',
#   'Sample 3 (d)(4).jpg',
#   'Sample 3 (d).jpg',
#   'Sample 3(a)(1).jpg',
#   'Sample 3(a)(2).jpg',
#   'Sample 3(a)(3).jpg',
#   'Sample 3(a)(4).jpg',
#   'Sample 3(a).jpg',
#   'Sample 3(b).jpg',
#   'Sample 3(c).jpg',
#   'Sample 4 (a)(1).jpg',
#   'Sample 4 (a)(2).jpg',
#   'Sample 4 (a)(3).jpg',
#   'Sample 4 (a).jpg',
#   'Sample 4 (b)(1).jpg',
#   'Sample 4 (b)(2).jpg',
#   'Sample 4 (b)(3).jpg',
#   'Sample 4 (b)(4).jpg',
#   'Sample 4 (b)(5).jpg',
#   'Sample 4 (b).jpg',
#   'Sample 5 (b)(2).jpg',
#   'Sample 5 (b)(3).jpg',
#   'Sample 5 (b)(4).jpg',
#   'Sample 5 (b).jpg',
#   'Sample 5 (c)(1).jpg',
#   'Sample 5 (c)(2).jpg',
#   'Sample 5 (c)(3).jpg',
#   'Sample 5 (c)(4).jpg',
#   'Sample 5 (c).jpg',
#   'Sample 5 (d)(1).jpg',
#   'Sample 5 (d)(2).jpg',
#   'Sample 5 (d)(3).jpg',
#   'Sample 5 (d)(4).jpg',
#   'Sample 5 (d)(5).jpg',
#   'Sample 5 (d).jpg',
#   'Sample 5(a).jpg',
#   'Sample 5(b).jpg',
#   'Sample 5(c).jpg',
#   'Sample 1(c)(4).jpg',
#   'Sample 2(d)(1).jpg',
#   'Sample 4 (c)(1).jpg',
#   'Sample 5 (b)(1).jpg',
#   'Sample 1(c)(5).jpg',
#   'Sample 1(c)(6).jpg',
#   'Sample 1(c).jpg',
#   'Sample 1(d)(1).jpg',
#   'Sample 1(d)(2).jpg',
#   'Sample 1(d)(3).jpg',
#   'Sample 1(d)(4).jpg',
#   'Sample 1(d)(5).jpg',
#   'Sample 1(d).jpg',
#   'Sample 2 (c).jpg',
#   'Sample 2(a)(1).jpg',
#   'Sample 2(a)(2).jpg',
#   'Sample 2(a)(3).jpg',
#   'Sample 2(a)(4).jpg',
#   'Sample 2(a).jpg',
#   'Sample 2(b)(1).jpg',
#   'Sample 2(b)(2).jpg',
#   'Sample 2(b)(3).jpg',
#   'Sample 2(b)(4).jpg',
#   'Sample 2(b).jpg',
#   'Sample 2(c)(1).jpg',
#   'Sample 2(c)(2).jpg',
#   'Sample 2(c)(3).jpg',
#   'Sample 2(c)(4).jpg',
#   'Sample 2(c).jpg']}

# %%
sizes = [len(data['Good']), len(data['Intermediate']), len(data['Bad'])]
plt.figure(figsize=(10,5), dpi=100)
plt.pie(x=sizes,autopct='%1.0f%%',shadow=False, textprops={'color':"w","fontsize":15}, startangle=90)
plt.legend(files,bbox_to_anchor=(0.4, 0, .7, 1))
plt.title("Data Split")
plt.show()

# %%
width = 100
height = 100
start = time.time()
image_data = []
image_target = []

for title in files:
    os.chdir(address+title)
    counter = 0
    for i in data[title]:
        img = cv2.imread(i)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
        image_data.append(cv2.resize(img,(width, height)))
        image_target.append(title)
        counter += 1
#         if counter == sample_size:
#             break
    clear_output(wait=True)
    print("Compiled Class",title)
calculate_time = time.time() - start    
print("Calculate Time",round(calculate_time,5))
# Out:
# Compiled Class Bad
# Calculate Time 35.16372

# %%
image_data = np.array(image_data)
size = image_data.shape[0]
image_data.shape
# Out:
# (310, 100, 100, 3)

# %%
plt.figure(figsize=(15,15))
for i in range(1,17):
    fig = np.random.choice(np.arange(size))
    plt.subplot(4,4,i)
    plt.imshow(image_data[fig])
    if image_target[fig]=='Good':
        c='green'
    elif image_target[fig]=='Intermediate':
        c='yellow'
    else:
        c='red'
    plt.title(image_target[fig], color=c)
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models

from sklearn.preprocessing import LabelEncoder

from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       3 from tensorflow.keras import datasets, layers, models
#       5 from sklearn.preprocessing import LabelEncoder
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
labels = LabelEncoder()
labels.fit(image_target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 labels = LabelEncoder()
#       2 labels.fit(image_target)
#
# NameError: name 'LabelEncoder' is not defined

# %%
X = image_data / 255.0
y = labels.transform(image_target)
train_images, test_images, train_labels, test_labels = train_test_split(X,y, test_size=0.3, random_state=123)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 2>()
#       1 X = image_data / 255.0
# ----> 2 y = labels.transform(image_target)
#       3 train_images, test_images, train_labels, test_labels = train_test_split(X,y, test_size=0.3, random_state=123)
#
# NameError: name 'labels' is not defined

# %%
model = models.Sequential()
model.add(layers.Conv2D(35, (3, 3), activation='relu', input_shape=(width,height,3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 model = models.Sequential()
#       2 model.add(layers.Conv2D(35, (3, 3), activation='relu', input_shape=(width,height,3)))
#       3 model.add(layers.MaxPooling2D((2, 2)))
#
# NameError: name 'models' is not defined

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 model.add(layers.Flatten())
#       2 model.add(layers.Dense(64, activation='relu'))
#       3 model.add(layers.Dense(2))
#
# NameError: name 'model' is not defined

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 model.compile(optimizer='adam',
#       2               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#       3               metrics=['accuracy'])
#       5 history = model.fit(train_images, train_labels, epochs=10,
#       6                     validation_data=(test_images, test_labels))
#
# NameError: name 'model' is not defined
