# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import time
import os
from IPython.display import clear_output
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# Case 1: Prediction in RGB Color Space

# %%
# Preparing the dataset
files = ['Consumable', 'Non-Consumable']
address = '/media/debrc/Data/Codings/Meat-Gradation-PROJ/Dataset/Prawn/'

# %%
# Loading the image files based on classifications
data = {}
for f in files:
    data[f]=[]
for col in files:
    os.chdir(address+col)
    for i in os.listdir(os.getcwd()):
        if i.endswith('.jpg'):
            data[col].append(i)

# %%
sizes = [len(data['Consumable']), len(data['Non-Consumable'])]
plt.figure(figsize=(10,5), dpi=100)
plt.pie(x=sizes,autopct='%1.0f%%',shadow=False, textprops={'color':"w","fontsize":15}, startangle=90)
plt.legend(files,bbox_to_anchor=(0.4, 0, .7, 1))
plt.title("Data Split")
plt.show()

# %%
width = 100
height = 100

# %%
# Converting BGR Images to RGB Color Space
start = time.time()
image_data = []
image_target = []

for title in files:
    os.chdir(address+title)
    counter = 0
    for i in data[title]:
        img = cv2.imread(i)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        image_data.append(cv2.resize(img,(width, height)))
        image_target.append(title)
        counter += 1
    clear_output(wait=True)
calculate_time = time.time() - start    
print("Calculate Time",round(calculate_time,5))
# Out:
# Calculate Time 64.23456

# %%
# Displaying the dimensionality of the array
image_data = np.array(image_data)
size = image_data.shape[0]
image_data.shape
# Out:
# (122, 100, 100, 3)

# %%
plt.figure(figsize=(15,15))
for i in range(1,17):
    fig = np.random.choice(np.arange(size))
    plt.subplot(4,4,i)
    plt.imshow(image_data[fig])
    if image_target[fig]=='Consumable':
        c='green'
    else:
        c='red'
    plt.title(image_target[fig], color=c)
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Making labels for the data
labels = LabelEncoder()
labels.fit(image_target)
# Out:
# LabelEncoder()

# %%
# Transforming image_data rgb values within 0 to 1
X = image_data / 255.0
# Transforming labels to distinct integer values
y = labels.transform(image_target)
train_images, test_images, train_labels, test_labels = train_test_split(X,y, test_size=0.3, random_state=123)

# %%
# ResNet model
def resnet_model(input_shape=(width,height,3)):
    # Load the ResNet50 model without the top layers
    resnet = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)

    # Add custom top layers for classification
    x = layers.Flatten()(resnet.output)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(64, activation='relu')(x)
    predictions = layers.Dense(1, activation='sigmoid')(x)

    # Create the model
    model = models.Model(inputs=resnet.input, outputs=predictions)

    # Freeze the ResNet50 layers
    for layer in resnet.layers:
        layer.trainable = False

    return model

# Create model
model = resnet_model()

# Training model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 9s 2s/step - loss: 3.0876 - accuracy: 0.5176 - val_loss: 0.7982 - val_accuracy: 0.5135
# Epoch 2/10
# 3/3 [==============================] - 6s 2s/step - loss: 0.7248 - accuracy: 0.5059 - val_loss: 0.6988 - val_accuracy: 0.5135
# Epoch 3/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.7210 - accuracy: 0.6000 - val_loss: 0.7231 - val_accuracy: 0.5135
# Epoch 4/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.6550 - accuracy: 0.6235 - val_loss: 0.6881 - val_accuracy: 0.5135
# Epoch 5/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.7197 - accuracy: 0.4353 - val_loss: 0.7189 - val_accuracy: 0.5135
# Epoch 6/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.6870 - accuracy: 0.6941 - val_loss: 0.6789 - val_accuracy: 0.5135
# Epoch 7/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.6420 - accuracy: 0.6000 - val_loss: 0.7517 - val_accuracy: 0.5135
# Epoch 8/10
# 3/3 [==============================] - 4s 1s/step - loss: 0.7057 - accuracy: 0.6000 - val_loss: 0.6860 - val_accuracy: 0.5135
# Epoch 9/10
# 3/3 [==============================] - 4s 1s/step - loss: 0.6366 - accuracy: 0.6118 - val_loss: 0.6611 - val_accuracy: 0.5676
# Epoch 10/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.6386 - accuracy: 0.7294 - val_loss: 0.7080 - val_accuracy: 0.5135

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1.01])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 2/2 - 1s - loss: 0.7080 - accuracy: 0.5135 - 1s/epoch - 608ms/step

# %%
result=model.evaluate(test_images, test_labels)
# Out:
# 2/2 [==============================] - 2s 403ms/step - loss: 0.7080 - accuracy: 0.5135

# %%
for i in range(len(model.metrics_names)):
    print(model.metrics_names[i],":",result[i])
# Out:
# loss : 0.7080493569374084
# accuracy : 0.5135135054588318

# %%
# Calculating Accuracy

y_pred = model.predict(test_images)

def toClass(pred):
    
    class_ = np.zeros(len(pred))
    for i in range(len(pred)):
        index = pred[i].argmax()
        class_[i] = index
        
    return class_

cm = confusion_matrix(test_labels,toClass(y_pred))

df1 = pd.DataFrame(columns=["Consumable","Non-Consumable"], index= ["Consumable","Non-Consumable"], data= cm )

f,ax = plt.subplots(figsize=(6,6))

sns.heatmap(df1, annot=True,cmap="Greens", fmt= '.0f',ax=ax,linewidths = 5, cbar = False,annot_kws={"size": 16})
plt.xlabel("Predicted Label")
plt.xticks(size = 12)
plt.yticks(size = 12, rotation = 0)
plt.ylabel("True Label")
plt.show()
# Out:
# 2/2 [==============================] - 5s 235ms/step

# %%
# Case 1: Prediction in HSV Color Space

# %%
# Preparing the dataset
files = ['Consumable', 'Non-Consumable']
address = '/media/debrc/Data/Codings/Meat-Gradation-PROJ/Dataset/Prawn/'

# %%
# Loading the image files based on classifications
data = {}
for f in files:
    data[f]=[]
for col in files:
    os.chdir(address+col)
    for i in os.listdir(os.getcwd()):
        if i.endswith('.jpg'):
            data[col].append(i)

# %%
sizes = [len(data['Consumable']), len(data['Non-Consumable'])]
plt.figure(figsize=(10,5), dpi=100)
plt.pie(x=sizes,autopct='%1.0f%%',shadow=False, textprops={'color':"w","fontsize":15}, startangle=90)
plt.legend(files,bbox_to_anchor=(0.4, 0, .7, 1))
plt.title("Data Split")
plt.show()

# %%
width = 100
height = 100

# %%
# Converting BGR Images to HSV Color Space
start = time.time()
image_data = []
image_target = []

for title in files:
    os.chdir(address+title)
    counter = 0
    for i in data[title]:
        img = cv2.imread(i)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        image_data.append(cv2.resize(img,(width, height)))
        image_target.append(title)
        counter += 1
    clear_output(wait=True)
calculate_time = time.time() - start    
print("Calculate Time",round(calculate_time,5))
# Out:
# Calculate Time 67.0981

# %%
# Displaying the dimensionality of the array
image_data = np.array(image_data)
size = image_data.shape[0]
image_data.shape
# Out:
# (122, 100, 100, 3)

# %%
plt.figure(figsize=(15,15))
for i in range(1,17):
    fig = np.random.choice(np.arange(size))
    plt.subplot(4,4,i)
    plt.imshow(image_data[fig])
    if image_target[fig]=='Consumable':
        c='green'
    else:
        c='red'
    plt.title(image_target[fig], color=c)
    plt.xticks([]), plt.yticks([])
plt.show()

# %%
# Making labels for the data
labels = LabelEncoder()
labels.fit(image_target)
# Out:
# LabelEncoder()

# %%
# Transforming image_data rgb values within 0 to 1
X = image_data
# Transforming labels to distinct integer values
y = labels.transform(image_target)
train_images, test_images, train_labels, test_labels = train_test_split(X,y, test_size=0.3, random_state=123)

# %%
# ResNet model
def resnet_model(input_shape=(width,height,3)):
    # Load the ResNet50 model without the top layers
    resnet = tf.keras.applications.ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)

    # Add custom top layers for classification
    x = layers.Flatten()(resnet.output)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dense(64, activation='relu')(x)
    predictions = layers.Dense(1, activation='sigmoid')(x)

    # Create the model
    model = models.Model(inputs=resnet.input, outputs=predictions)

    # Freeze the ResNet50 layers
    for layer in resnet.layers:
        layer.trainable = False

    return model

# Create model
model = resnet_model()

# Training model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 3/3 [==============================] - 9s 2s/step - loss: 4.2130 - accuracy: 0.5647 - val_loss: 0.4690 - val_accuracy: 0.8649
# Epoch 2/10
# 3/3 [==============================] - 4s 1s/step - loss: 0.4189 - accuracy: 0.8353 - val_loss: 1.4419 - val_accuracy: 0.7027
# Epoch 3/10
# 3/3 [==============================] - 3s 1s/step - loss: 0.1383 - accuracy: 0.9412 - val_loss: 0.3401 - val_accuracy: 0.8649
# Epoch 4/10
# 3/3 [==============================] - 4s 2s/step - loss: 0.1306 - accuracy: 0.9412 - val_loss: 1.3808 - val_accuracy: 0.8108
# Epoch 5/10
# 3/3 [==============================] - 4s 2s/step - loss: 0.0514 - accuracy: 0.9882 - val_loss: 2.0502 - val_accuracy: 0.7297
# Epoch 6/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0430 - accuracy: 0.9882 - val_loss: 0.7748 - val_accuracy: 0.8919
# Epoch 7/10
# 3/3 [==============================] - 4s 2s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.3155 - val_accuracy: 0.8919
# Epoch 8/10
# 3/3 [==============================] - 5s 2s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.2470 - val_accuracy: 0.9189
# Epoch 9/10
# 3/3 [==============================] - 4s 2s/step - loss: 5.9611e-04 - accuracy: 1.0000 - val_loss: 0.3110 - val_accuracy: 0.8649
# Epoch 10/10
# 3/3 [==============================] - 4s 2s/step - loss: 1.4035e-04 - accuracy: 1.0000 - val_loss: 0.4302 - val_accuracy: 0.8919

# %%
plt.style.use('ggplot')
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1.01])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 2/2 - 1s - loss: 0.4302 - accuracy: 0.8919 - 1s/epoch - 639ms/step

# %%
result=model.evaluate(test_images, test_labels)
# Out:
# 2/2 [==============================] - 1s 211ms/step - loss: 0.4302 - accuracy: 0.8919

# %%
for i in range(len(model.metrics_names)):
    print(model.metrics_names[i],":",result[i])
# Out:
# loss : 0.4301915168762207
# accuracy : 0.8918918967247009

# %%
# Calculating Accuracy

y_pred = model.predict(test_images)

def toClass(pred):
    
    class_ = np.zeros(len(pred))
    for i in range(len(pred)):
        index = pred[i].argmax()
        class_[i] = index
        
    return class_

cm = confusion_matrix(test_labels,toClass(y_pred))

df1 = pd.DataFrame(columns=["Consumable","Non-Consumable"], index= ["Consumable","Non-Consumable"], data= cm )

f,ax = plt.subplots(figsize=(6,6))

sns.heatmap(df1, annot=True,cmap="Greens", fmt= '.0f',ax=ax,linewidths = 5, cbar = False,annot_kws={"size": 16})
plt.xlabel("Predicted Label")
plt.xticks(size = 12)
plt.yticks(size = 12, rotation = 0)
plt.ylabel("True Label")
plt.show()
# Out:
# 2/2 [==============================] - 2s 171ms/step
